# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics.pairwise import cosine_similarity
from pprint import pprint
import time

# %% [markdown]
# ---
# Low Rank Matrix Factorization with Mean Normalization
# =====
# ***

# %%
data = pd.read_csv("book_rating.csv")

# %%
del(data['Unnamed: 0'])

# %%
new_index = data['Book Title']

# %%
data.index = new_index

# %%
del(data['Book Title'])

# %%
cols = range(0, 6)
data.columns = cols

# %%
data_orig = data.copy()

# %%
data.head()
# Out:
#                                                   0  1  2  3  4  5
# Book Title
# The Horse Whisperer                               0 -1  1  0  9 -1
# The Vampire Lestat (Vampire Chronicles, Book II) -1  0  8 -1 -1 -1
# The Hours: A Novel                               -1 -1  9 -1  8  0
# While I Was Gone                                  0  0  0  8  0  0
# Sphere                                            0  0  0 -1  0 -1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 98 entries, The Horse Whisperer to The Brethren
# Data columns (total 6 columns):
# 0    98 non-null int64
# 1    98 non-null int64
# 2    98 non-null int64
# 3    98 non-null int64
# 4    98 non-null int64
# 5    98 non-null int64
# dtypes: int64(6)
# memory usage: 5.4+ KB

# %%
#i indexes the movie, j the user
def r(i, j, data):
    '''This checks to see if the user has reviewed a book (as indicated by the presence of a -1).
    If they have reviewed the book then this function returns a 1'''
    
    ulist = data.iloc[i]
    if ulist[j] != -1:
        return 1
    else:
        return 0

# %%
def y(i, j, data):
    '''This function returns the rating provided by the user for the book'''
    
    ulist = data.iloc[i]
    return ulist[j]

# %% [markdown]
# #####Compute the average rating each movie gets
# #####The average is the sum of all the ratings over the number of ratings - do not include the users who have not rated the movie yet

# %%
def get_mean_vector(nu, nm, data):
    '''This function calculates the mean vector for each book using all users who have rated that movie'''
    
    mean_vector = np.zeros(nm)
    for i in xrange(nm):
        if i % 1000 == 0:
            print '.',
            time.sleep(1)
        mean_vector[i] = 0.0
        count = 0
        for j in xrange(nu):
            if r(i, j, data):
                count += 1
                mean_vector[i] += y(i, j, data)
        mean_vector[i] /= float(count)
    print "\n"
    return mean_vector

# %%
nu = 6
nm = 98
mean_vector = get_mean_vector(nu, nm, data)
print mean_vector
# Out:
#  .
#
# [ 2.5         4.          5.66666667  1.33333333  0.          7.5         0.
#   5.6         0.          5.          1.4         5.33333333  1.33333333
#   2.33333333  6.25        8.5         1.6         3.33333333  2.5
#   3.33333333  3.75        2.66666667  0.          2.25        3.          0.
#   0.          5.66666667  5.33333333  3.8         6.75        3.4         2.
#   2.5         3.33333333  4.2         5.          7.5         1.6         0.25
#   5.6         1.33333333  5.33333333  0.          3.2         5.          2.
#   0.          3.83333333  3.75        3.6         0.66666667  2.75        5.
#   3.5         2.4         2.8         2.66666667  6.4         2.
#   3.16666667  2.          3.          4.33333333  1.2         0.66666667
#   2.          2.25        1.75        6.5         3.25        1.75        5.4
#   2.25        3.33333333  4.16666667  3.2         0.          3.2
#   4.66666667  0.          2.5         3.          5.4         2.6         2.25
#   4.5         0.          5.66666667  4.6         1.33333333  5.75        4.
#   0.          1.5         5.66666667  1.33333333  2.        ]

# %%
def subtract_mv_from_dataframe(nu, nm, mean_vector, data):
    '''This function subtracts the mean vector from each book rating, leaving the books that have not been
    rated yet by any given users as they were'''
    
    for i in xrange(nm):
        for j in xrange(nu):
            if r(i, j, data):
                data.iloc[i, j] -= mean_vector[i]
    return(data)

# %%
data = subtract_mv_from_dataframe(nu, nm, mean_vector, data)

# %%
data
# Out:
#                                                            0         1  \
# Book Title
# The Horse Whisperer                                -2.500000 -1.000000
# The Vampire Lestat (Vampire Chronicles, Book II)   -1.000000 -4.000000
# The Hours: A Novel                                 -1.000000 -1.000000
# While I Was Gone                                   -1.333333 -1.333333
# Sphere                                              0.000000  0.000000
# The Red Tent (Bestselling Backlist)                -7.500000  2.500000
# The Chamber                                         0.000000  0.000000
# The Notebook                                       -5.600000 -5.600000
# Harry Potter and the Order of the Phoenix (Book 5)  0.000000  0.000000
# The Lovely Bones: A Novel                          -5.000000  1.000000
# Little Altars Everywhere: A Novel                  -1.400000 -1.400000
# Good in Bed                                        -5.333333  1.666667
# A Painted House                                    -1.333333 -1.333333
# The Handmaid's Tale                                -2.333333 -2.333333
# A Map of the World                                 -1.000000 -1.000000
# The Five People You Meet in Heaven                 -1.000000 -1.000000
# The Perfect Storm : A True Story of Men Against... -1.600000 -1.600000
# Confessions of a Shopaholic (Summer Display Opp... -1.000000 -3.333333
# Harry Potter and the Chamber of Secrets (Book 2)   -1.000000 -2.500000
# Me Talk Pretty One Day                             -1.000000 -1.000000
# The Catcher in the Rye                             -3.750000 -1.000000
# Jurassic Park                                      -1.000000 -1.000000
# American Gods                                       0.000000  0.000000
# The Testament                                      -2.250000 -2.250000
# Mystic River                                       -1.000000 -3.000000
# The Queen of the Damned (Vampire Chronicles (Pa... -1.000000 -1.000000
# A Heartbreaking Work of Staggering Genius           0.000000 -1.000000
# Icy Sparks                                         -1.000000 -5.666667
# Wicked: The Life and Times of the Wicked Witch ... -1.000000 -1.000000
# Snow Falling on Cedars                             -3.800000 -1.000000
# ...                                                      ...       ...
# The Book of Ruth (Oprah's Book Club (Paperback))   -1.750000 -1.000000
# 1st to Die: A Novel                                -6.500000  0.500000
# Hannibal                                           -3.250000 -3.250000
# The Alienist                                       -1.750000 -1.750000
# Fahrenheit 451                                     -5.400000  4.600000
# The Runaway Jury                                   -2.250000 -2.250000
# A Prayer for Owen Meany                            -1.000000 -1.000000
# The Joy Luck Club                                  -4.166667  3.833333
# Summer Sisters                                     -3.200000 -1.000000
# Red Dragon                                          0.000000 -1.000000
# The Summons                                        -3.200000 -3.200000
# The Secret Life of Bees                            -4.666667  3.333333
# The Partner                                         0.000000  0.000000
# The Client                                         -2.500000 -2.500000
# Timeline                                           -3.000000 -3.000000
# The Reader                                         -1.000000  0.600000
# Into Thin Air : A Personal Account of the Mt. E... -2.600000 -1.000000
# Angela's Ashes (MMP) : A Memoir                    -2.250000 -1.000000
# Where the Heart Is (Oprah's Book Club (Paperback)) -4.500000 -4.500000
# The Pilot's Wife : A Novel                          0.000000  0.000000
# The Nanny Diaries: A Novel                         -5.666667  2.333333
# House of Sand and Fog                              -1.000000 -4.600000
# Message in a Bottle                                 6.666667 -1.333333
# Fall On Your Knees (Oprah #45)                     -1.000000 -1.000000
# Harry Potter and the Sorcerer's Stone (Harry Po... -4.000000  6.000000
# A Time to Kill                                      0.000000  0.000000
# The Pelican Brief                                  -1.500000 -1.500000
# Balzac and the Little Chinese Seamstress : A Novel -1.000000  2.333333
# Angels &amp; Demons                                -1.333333 -1.333333
# The Brethren                                       -2.000000 -2.000000
#
#                                                            2         3  \
# Book Title
# The Horse Whisperer                                -1.500000 -2.500000
# The Vampire Lestat (Vampire Chronicles, Book II)    4.000000 -1.000000
# The Hours: A Novel                                  3.333333 -1.000000
# While I Was Gone                                   -1.333333  6.666667
# Sphere                                              0.000000 -1.000000
# The Red Tent (Bestselling Backlist)                 2.500000  1.500000
# The Chamber                                         0.000000  0.000000
# The Notebook                                        4.400000  2.400000
# Harry Potter and the Order of the Phoenix (Book 5)  0.000000 -1.000000
# The Lovely Bones: A Novel                           0.000000  4.000000
# Little Altars Everywhere: A Novel                  -1.400000 -1.000000
# Good in Bed                                         2.666667 -5.333333
# A Painted House                                     6.666667 -1.333333
# The Handmaid's Tale                                 4.666667 -1.000000
# A Map of the World                                  1.750000 -6.250000
# The Five People You Meet in Heaven                  0.500000 -1.000000
# The Perfect Storm : A True Story of Men Against...  6.400000 -1.600000
# Confessions of a Shopaholic (Summer Display Opp...  6.666667 -1.000000
# Harry Potter and the Chamber of Secrets (Book 2)    7.500000 -2.500000
# Me Talk Pretty One Day                              6.666667 -1.000000
# The Catcher in the Rye                             -3.750000 -1.000000
# Jurassic Park                                       5.333333 -1.000000
# American Gods                                       0.000000 -1.000000
# The Testament                                       6.750000 -1.000000
# Mystic River                                        3.000000 -1.000000
# The Queen of the Damned (Vampire Chronicles (Pa...  0.000000 -1.000000
# A Heartbreaking Work of Staggering Genius           0.000000  0.000000
# Icy Sparks                                          2.333333 -1.000000
# Wicked: The Life and Times of the Wicked Witch ...  3.666667 -5.333333
# Snow Falling on Cedars                              6.200000  5.200000
# ...                                                      ...       ...
# The Book of Ruth (Oprah's Book Club (Paperback))    5.250000 -1.000000
# 1st to Die: A Novel                                 3.500000 -1.000000
# Hannibal                                            4.750000 -1.000000
# The Alienist                                        5.250000 -1.000000
# Fahrenheit 451                                     -5.400000 -1.000000
# The Runaway Jury                                    6.750000 -1.000000
# A Prayer for Owen Meany                             6.666667 -3.333333
# The Joy Luck Club                                  -4.166667  4.833333
# Summer Sisters                                      3.800000 -3.200000
# Red Dragon                                          0.000000 -1.000000
# The Summons                                         4.800000 -3.200000
# The Secret Life of Bees                             5.333333 -4.666667
# The Partner                                         0.000000 -1.000000
# The Client                                          2.500000 -1.000000
# Timeline                                            7.000000 -3.000000
# The Reader                                          2.600000  2.600000
# Into Thin Air : A Personal Account of the Mt. E...  5.400000 -2.600000
# Angela's Ashes (MMP) : A Memoir                     6.750000 -2.250000
# Where the Heart Is (Oprah's Book Club (Paperback))  5.500000  4.500000
# The Pilot's Wife : A Novel                          0.000000  0.000000
# The Nanny Diaries: A Novel                          3.333333 -5.666667
# House of Sand and Fog                               2.400000 -4.600000
# Message in a Bottle                                -1.333333 -1.333333
# Fall On Your Knees (Oprah #45)                      0.250000 -5.750000
# Harry Potter and the Sorcerer's Stone (Harry Po...  6.000000 -4.000000
# A Time to Kill                                      0.000000 -1.000000
# The Pelican Brief                                  -1.500000 -1.000000
# Balzac and the Little Chinese Seamstress : A Novel  3.333333 -5.666667
# Angels &amp; Demons                                 6.666667 -1.333333
# The Brethren                                        6.000000 -2.000000
#
#                                                            4         5
# Book Title
# The Horse Whisperer                                 6.500000 -1.000000
# The Vampire Lestat (Vampire Chronicles, Book II)   -1.000000 -1.000000
# The Hours: A Novel                                  2.333333 -5.666667
# While I Was Gone                                   -1.333333 -1.333333
# Sphere                                              0.000000 -1.000000
# The Red Tent (Bestselling Backlist)                 1.500000 -0.500000
# The Chamber                                         0.000000 -1.000000
# The Notebook                                        4.400000 -1.000000
# Harry Potter and the Order of the Phoenix (Book 5) -1.000000 -1.000000
# The Lovely Bones: A Novel                           5.000000 -5.000000
# Little Altars Everywhere: A Novel                   5.600000 -1.400000
# Good in Bed                                         3.666667  2.666667
# A Painted House                                    -1.333333 -1.333333
# The Handmaid's Tale                                -1.000000 -1.000000
# A Map of the World                                  2.750000  1.750000
# The Five People You Meet in Heaven                 -0.500000 -1.000000
# The Perfect Storm : A True Story of Men Against... -1.000000 -1.600000
# Confessions of a Shopaholic (Summer Display Opp... -3.333333 -1.000000
# Harry Potter and the Chamber of Secrets (Book 2)   -1.000000 -2.500000
# Me Talk Pretty One Day                             -3.333333 -3.333333
# The Catcher in the Rye                              4.250000  3.250000
# Jurassic Park                                      -2.666667 -2.666667
# American Gods                                      -1.000000 -1.000000
# The Testament                                      -2.250000 -1.000000
# Mystic River                                       -1.000000 -1.000000
# The Queen of the Damned (Vampire Chronicles (Pa... -1.000000 -1.000000
# A Heartbreaking Work of Staggering Genius           0.000000  0.000000
# Icy Sparks                                          3.333333 -1.000000
# Wicked: The Life and Times of the Wicked Witch ... -1.000000  1.666667
# Snow Falling on Cedars                             -3.800000 -3.800000
# ...                                                      ...       ...
# The Book of Ruth (Oprah's Book Club (Paperback))   -1.750000 -1.750000
# 1st to Die: A Novel                                 2.500000 -1.000000
# Hannibal                                            1.750000 -1.000000
# The Alienist                                       -1.750000 -1.000000
# Fahrenheit 451                                      2.600000  3.600000
# The Runaway Jury                                   -2.250000 -1.000000
# A Prayer for Owen Meany                            -3.333333 -1.000000
# The Joy Luck Club                                  -4.166667  3.833333
# Summer Sisters                                      5.800000 -3.200000
# Red Dragon                                         -1.000000 -1.000000
# The Summons                                         4.800000 -1.000000
# The Secret Life of Bees                             5.333333 -4.666667
# The Partner                                         0.000000 -1.000000
# The Client                                          2.500000 -1.000000
# Timeline                                            2.000000 -1.000000
# The Reader                                         -0.400000 -5.400000
# Into Thin Air : A Personal Account of the Mt. E...  2.400000 -2.600000
# Angela's Ashes (MMP) : A Memoir                    -1.000000 -2.250000
# Where the Heart Is (Oprah's Book Club (Paperback))  3.500000 -4.500000
# The Pilot's Wife : A Novel                          0.000000  0.000000
# The Nanny Diaries: A Novel                          3.333333  2.333333
# House of Sand and Fog                               4.400000  2.400000
# Message in a Bottle                                -1.333333 -1.333333
# Fall On Your Knees (Oprah #45)                      3.250000  2.250000
# Harry Potter and the Sorcerer's Stone (Harry Po... -1.000000 -4.000000
# A Time to Kill                                      0.000000 -1.000000
# The Pelican Brief                                   4.500000 -1.000000
# Balzac and the Little Chinese Seamstress : A Novel -1.000000 -1.000000
# Angels &amp; Demons                                -1.333333 -1.333333
# The Brethren                                       -1.000000 -1.000000
#
# [98 rows x 6 columns]

# %%
def x_update(alpha, x, t, nk, k, i, nu, nm, data, lam):
    '''This is the partial derivative equation required to update the book features'''
    
    tsum = 0.0
    #loop over the number of users
    for j in xrange(nu):
        
        #if the movie was reviewed
        if r(i, j, data):
            tt = t[j]
            tt = tt.reshape(nk, 1)
            
            #theta transpze x - y
            temp = np.dot(tt.T, x[i]) - y(i, j, data)
            
            temp1 = temp * t[j][k]
            tsum += temp1
            
    #regularize
    tsum += lam * x[i][k]
    return x[i][k] - alpha * tsum

# %%
def t_update(alpha, x, t, nk, k, j, nu, nm, data, lam):
    '''This is the partial derivative equation required to update the user parameters, theta'''
    
    tsum = 0.0
    #loop over the movies
    for i in xrange(nm):
        
        #if the movie was reviewed
        if r(i, j, data):
            tt = t[j]
            tt = tt.reshape(nk, 1)
            
            #theta transpose x - y
            temp = np.dot(tt.T, x[i]) - y(i, j, data)
            
            temp1 = temp * x[i][k]
            tsum += temp1
            
    #regularize
    tsum += lam * t[j][k]
    return t[j][k] - alpha * tsum

# %%
def J_Cost(x, t, nk, nu, nm, data, lam):
    '''This is the cost function that we are minimizing with gradient descent'''
    
    tsum = 0.0
    txsum = 0.0
    ttsum = 0.0
    
    #loop over all the movies and all the users
    for i in xrange(nm):
        for j in xrange(nu):
            
            #if a user has reviewed a movie then process
            if r(i, j, data):
                tt = t[j]
                tt = tt.reshape(nk, 1)
                
                #this is the squared error
                temp = (np.dot(tt.T, x[i]) - y(i, j, data)) * (np.dot(tt.T, x[i]) - y(i, j, data))
                
                #the sum of the squared errors is accumulated here
                tsum += temp
                
    #this is the regularization for the movie features, x
    for i in xrange(nm):
        for k in xrange(nk):
            txsum += x[i][k] * x[i][k]   

    #this is the regularization for the user parameters, theta
    for j in xrange(nu):
        for k in xrange(nk):
            ttsum += t[j][k] * t[j][k]
        
    #return the result
    res = (0.5 * tsum) + (lam/2.0 * txsum) + (lam/2.0 * ttsum)
    return res

# %%
def lrmf(nm = 5, nu = 4, nk = 5, n_iterations = 100, alpha = 0.01, lam = 0.1):
    '''This is the routine that will return a feature set for the movies, x, and a parameter set for users, theta
    number of movies is nm
    number of users is nu
    number of features is nk
    the learning rate is alpha
    the regularization parameter (L2) is lam'''
    
    #set up the array for the features, and a temporary array
    x = np.zeros((nm, nk))
    tempx = np.zeros((nm, nk))

    #initialize to small random values
    for a in xrange(nm):
        for b in xrange(nk):
            x[a][b] = (np.random.rand() - 0.5)/10.0

        
    #set up the array for the user parameters, theta, and a temporary array
    t = np.zeros((nu, nk))
    tempt = np.zeros((nu, nk))

    #initialize to small random values
    for a in xrange(nu):
        for b in xrange(nk):
            t[a][b] = (np.random.rand() - 0.5)/10.0

    #A variable to accumulate the cost function
    Jcost = []

    for n in xrange(n_iterations):
        
        Jcos =  J_Cost(x, t, nk, nu, nm, data, lam)
        print '.',
        Jcost.append(Jcos)
    
        #get all the new variables and store them in a temporary variable
        for i in xrange(nm):
            for k in xrange(nk):
                tempx[i][k] = x_update(alpha, x, t, nk, k, i, nu, nm, data, lam)
        
        #get all the new variables and store them in a temporary variable
        for j in xrange(nu):
            for k in xrange(nk):
                tempt[j][k] = t_update(alpha, x, t, nk, k, j, nu, nm, data, lam)
        
        
        #now do the updates
        for i in xrange(nm):
            for k in xrange(nk):
                x[i][k] = tempx[i][k]
        
        for j in xrange(nu):
            for k in xrange(nk):
                t[j][k] = tempt[j][k]
    return(x, t, Jcost)

# %% [markdown]
# #####Run the algorithm

# %%
#number of movies
#nm = 5

#number of users
#nu = 5 

#number of features to use
nk = 25 

#number of iterations for gradient descent
n_iterations = 250

#the learning rate
alpha = 0.01

#the regularization constant
lam = 0.1

x, t, Jcost = lrmf(nm = nm, nu = nu, nk = nk, n_iterations = n_iterations, alpha = alpha, lam = lam)
# Out:
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .

# %% [markdown]
# #####Caluculating the predicted ratings, x . theta_transpose
# #####Add the mean vector back onto the results

# %%
#take the transpose of the theta matrix
t_transpose = t.T

#take the inner product of x by theta transpose
res = np.dot(x, t_transpose)

#print res
#for i in xrange(nm):
#    for j in xrange(nu):
#        res[i][j] = res[i][j] + mean_vector[i]
#        print "{:5.2f}".format(res[i][j]),
#    print "\n"

# %% [markdown]
# #####Finding similar movies

# %%
#cs = cosine_similarity(res, res)
#for i in xrange(nm):
#    for j in xrange(nm):
#        print "{:10.3f}".format(cs[i][j]),
#    print "\n"

# %% [markdown]
# #####plot the cost function against iterations of gradient descent

# %%
#Plot the cost function over the number of iterations
fig = plt.figure(figsize = (5, 5))
ax = plt.subplot(111)
x_plot = np.linspace(0, n_iterations, n_iterations)
ax.plot(x_plot, Jcost)

# %%
#put the results into a data frame
def produce_predicted_dataframe(nu, t, nm, x, k, user_name_list, movie_list, mean_vector):
    '''This function produces a data frame which contains all the predictions from the model'''
    
    #assemble the data in a python dictionary
    p = {}
    
    #take the transpose of the theta matrix
    t_transpose = t.T

    #take the inner product of x by theta transpose
    res = np.dot(x, t_transpose)
    for j in xrange(nm):
        for i in xrange(nu):
            res[j][i] += mean_vector[i]

    for user in xrange(nu):
        p[user] = res[:,user]
    
    for k in xrange(nk):
        thestr = 'x'+str(int(k))
        p[thestr] = {}
        res = []
        for i in xrange(nm):
            res.append(x[i][k])
        p[thestr] = res
    
    p = pd.DataFrame(p)
    
    p.index.name = "Movie"
    p.columns.name = "User"
    
    for i in xrange(k + 1):
        the_str = 'x' + str(int(i))
        user_name_list.append(the_str)
    p.columns = name_list
    p.index = movie_list
    return p

# %% [markdown]
# #####Produce a data frame to compare with the original data frame

# %%
#using the original data frame get a list of the users
name_list = []
for j in xrange(nu):
    name_list.append(data.columns.values[j])

#using the original data frame get a list of the movies
movie_list = []
for i in xrange(nm):
    movie_list.append(data.index.values[i])
    
#assemble the data into a data frame
dataP = produce_predicted_dataframe(nu, t, nm, x, nk, name_list, movie_list, mean_vector)

# %%
format = lambda x: "{:0.2f}".format(x)

# %%
#dataP.applymap(format)
dataP[[0,1,2,3,4,5]].applymap(format)
# Out:
#                                                         0      1      2  \
# The Horse Whisperer                                  2.50   7.91   6.67
# The Vampire Lestat (Vampire Chronicles, Book II)     3.23   4.00  13.65
# The Hours: A Novel                                   3.17   5.85  14.66
# While I Was Gone                                     2.50   4.00   5.67
# Sphere                                               2.50   4.00   5.67
# The Red Tent (Bestselling Backlist)                  2.50  13.98  15.66
# The Chamber                                          2.50   4.00   5.67
# The Notebook                                         2.50   4.01  15.66
# Harry Potter and the Order of the Phoenix (Book 5)   2.50   4.00   5.67
# The Lovely Bones: A Novel                            2.50   9.99  10.67
# Little Altars Everywhere: A Novel                    2.50   4.00   5.67
# Good in Bed                                          2.50  10.99  13.66
# A Painted House                                      2.50   4.00  13.65
# The Handmaid's Tale                                  2.50   4.00  12.65
# A Map of the World                                   3.32   9.20  13.66
# The Five People You Meet in Heaven                   3.21   7.14  14.66
# The Perfect Storm : A True Story of Men Against...   2.50   4.00  13.65
# Confessions of a Shopaholic (Summer Display Opp...   2.91   4.00  15.65
# Harry Potter and the Chamber of Secrets (Book 2)     3.23   4.00  15.65
# Me Talk Pretty One Day                               3.13   4.05  15.65
# The Catcher in the Rye                               2.50   8.40   5.67
# Jurassic Park                                        2.96   4.06  13.65
# American Gods                                        2.50   4.00   5.67
# The Testament                                        2.50   4.00  14.65
# Mystic River                                         2.97   4.00  11.66
# The Queen of the Damned (Vampire Chronicles (Pa...   2.64   3.99   5.67
# A Heartbreaking Work of Staggering Genius            2.50   3.79   5.67
# Icy Sparks                                           3.43   4.01  13.66
# Wicked: The Life and Times of the Wicked Witch ...   3.31   8.22  14.65
# Snow Falling on Cedars                               2.50   4.43  15.65
# ...                                                   ...    ...    ...
# The Book of Ruth (Oprah's Book Club (Paperback))     2.50   4.16  12.65
# 1st to Die: A Novel                                  2.50  10.99  15.66
# Hannibal                                             2.50   4.01  13.66
# The Alienist                                         2.50   4.00  12.65
# Fahrenheit 451                                       2.50  13.98   5.68
# The Runaway Jury                                     2.50   4.00  14.65
# A Prayer for Owen Meany                              3.10   3.63  15.65
# The Joy Luck Club                                    2.50  11.98   5.67
# Summer Sisters                                       2.50   6.20  12.66
# Red Dragon                                           2.50   3.98   5.67
# The Summons                                          2.50   4.01  13.66
# The Secret Life of Bees                              2.50  11.98  15.66
# The Partner                                          2.50   4.00   5.67
# The Client                                           2.50   4.00  10.66
# Timeline                                             2.50   4.01  15.65
# The Reader                                           2.33   9.98  13.66
# Into Thin Air : A Personal Account of the Mt. E...   2.50   5.22  13.65
# Angela's Ashes (MMP) : A Memoir                      2.50   4.71  14.65
# Where the Heart Is (Oprah's Book Club (Paperback))   2.50   4.01  15.66
# The Pilot's Wife : A Novel                           2.50   4.00   5.67
# The Nanny Diaries: A Novel                           2.50  11.99  14.66
# House of Sand and Fog                                3.50   4.01  12.66
# Message in a Bottle                                 10.45   4.00   5.67
# Fall On Your Knees (Oprah #45)                       3.12   9.01  11.66
# Harry Potter and the Sorcerer's Stone (Harry Po...   2.50  13.97  15.65
# A Time to Kill                                       2.50   4.00   5.67
# The Pelican Brief                                    2.50   4.00   5.67
# Balzac and the Little Chinese Seamstress : A Novel   3.08  11.98  14.65
# Angels &amp; Demons                                  2.50   4.00  13.65
# The Brethren                                         2.50   4.00  13.65
#
#                                                         3      4      5
# The Horse Whisperer                                  1.34   8.98  11.86
# The Vampire Lestat (Vampire Chronicles, Book II)     2.76   3.24   8.17
# The Hours: A Novel                                   4.06   7.99   7.51
# While I Was Gone                                     9.30   0.00   7.50
# Sphere                                               1.40   0.00   7.39
# The Red Tent (Bestselling Backlist)                 10.31   9.00  14.49
# The Chamber                                          1.33  -0.00   7.51
# The Notebook                                         9.31   9.98   9.01
# Harry Potter and the Order of the Phoenix (Book 5)   1.51   0.03   7.49
# The Lovely Bones: A Novel                           10.31   9.98   7.51
# Little Altars Everywhere: A Novel                    2.99   6.98   7.51
# Good in Bed                                          1.34   8.99  15.48
# A Painted House                                      1.34   0.01   7.50
# The Handmaid's Tale                                  2.64   2.70   8.15
# A Map of the World                                   1.34   8.99  15.48
# The Five People You Meet in Heaven                   3.56   7.99  10.66
# The Perfect Storm : A True Story of Men Against...   1.34   2.53   7.50
# Confessions of a Shopaholic (Summer Display Opp...   2.64   0.01   6.94
# Harry Potter and the Chamber of Secrets (Book 2)     1.34   3.13   7.50
# Me Talk Pretty One Day                               2.28   0.01   7.50
# The Catcher in the Rye                               2.09   7.98  14.48
# Jurassic Park                                        2.03   0.01   7.50
# American Gods                                        1.22   0.10   7.51
# The Testament                                        2.38   0.01   6.96
# Mystic River                                         2.42   2.36   7.93
# The Queen of the Damned (Vampire Chronicles (Pa...   1.32  -0.06   7.54
# A Heartbreaking Work of Staggering Genius            1.33   0.00   7.50
# Icy Sparks                                           3.51   8.98   9.68
# Wicked: The Life and Times of the Wicked Witch ...   1.34   7.07  14.48
# Snow Falling on Cedars                              10.30   0.01   7.50
# ...                                                   ...    ...    ...
# The Book of Ruth (Oprah's Book Club (Paperback))     2.02   0.01   7.50
# 1st to Die: A Novel                                  4.16   8.99  12.09
# Hannibal                                             3.01   4.99   8.41
# The Alienist                                         2.43   0.01   6.93
# Fahrenheit 451                                       1.86   7.99  16.48
# The Runaway Jury                                     2.56   0.01   7.05
# A Prayer for Owen Meany                              1.34   0.01   6.90
# The Joy Luck Club                                   10.30   0.01  15.48
# Summer Sisters                                       1.34   8.98   7.51
# Red Dragon                                           1.32  -0.02   7.44
# The Summons                                          1.34   7.98   9.71
# The Secret Life of Bees                              1.34   9.98   7.52
# The Partner                                          1.33   0.00   7.49
# The Client                                           2.75   4.99   8.66
# Timeline                                             1.34   4.99   8.62
# The Reader                                           9.31   5.00   7.51
# Into Thin Air : A Personal Account of the Mt. E...   1.34   4.99   7.50
# Angela's Ashes (MMP) : A Memoir                      1.34   3.28   7.50
# Where the Heart Is (Oprah's Book Club (Paperback))  10.31   7.99   7.50
# The Pilot's Wife : A Novel                           1.33  -0.00   7.50
# The Nanny Diaries: A Novel                           1.34   8.99  15.49
# House of Sand and Fog                                1.34   8.98  14.48
# Message in a Bottle                                  1.33   0.00   7.50
# Fall On Your Knees (Oprah #45)                       1.34   8.99  15.48
# Harry Potter and the Sorcerer's Stone (Harry Po...   1.34   6.35   7.51
# A Time to Kill                                       1.35  -0.00   7.62
# The Pelican Brief                                    2.24   5.98   9.27
# Balzac and the Little Chinese Seamstress : A Novel   1.34   7.57  12.59
# Angels &amp; Demons                                  1.34   0.01   7.50
# The Brethren                                         1.34   2.84   8.18
#
# [98 rows x 6 columns]

# %%
data_orig
# Out:
#                                                     0   1   2  3   4  5
# Book Title
# The Horse Whisperer                                 0  -1   1  0   9 -1
# The Vampire Lestat (Vampire Chronicles, Book II)   -1   0   8 -1  -1 -1
# The Hours: A Novel                                 -1  -1   9 -1   8  0
# While I Was Gone                                    0   0   0  8   0  0
# Sphere                                              0   0   0 -1   0 -1
# The Red Tent (Bestselling Backlist)                 0  10  10  9   9  7
# The Chamber                                         0   0   0  0   0 -1
# The Notebook                                        0   0  10  8  10 -1
# Harry Potter and the Order of the Phoenix (Book 5)  0   0   0 -1  -1 -1
# The Lovely Bones: A Novel                           0   6   5  9  10  0
# Little Altars Everywhere: A Novel                   0   0   0 -1   7  0
# Good in Bed                                         0   7   8  0   9  8
# A Painted House                                     0   0   8  0   0  0
# The Handmaid's Tale                                 0   0   7 -1  -1 -1
# A Map of the World                                 -1  -1   8  0   9  8
# The Five People You Meet in Heaven                 -1  -1   9 -1   8 -1
# The Perfect Storm : A True Story of Men Against...  0   0   8  0  -1  0
# Confessions of a Shopaholic (Summer Display Opp... -1   0  10 -1   0 -1
# Harry Potter and the Chamber of Secrets (Book 2)   -1   0  10  0  -1  0
# Me Talk Pretty One Day                             -1  -1  10 -1   0  0
# The Catcher in the Rye                              0  -1   0 -1   8  7
# Jurassic Park                                      -1  -1   8 -1   0  0
# American Gods                                       0   0   0 -1  -1 -1
# The Testament                                       0   0   9 -1   0 -1
# Mystic River                                       -1   0   6 -1  -1 -1
# The Queen of the Damned (Vampire Chronicles (Pa... -1  -1   0 -1  -1 -1
# A Heartbreaking Work of Staggering Genius           0  -1   0  0   0  0
# Icy Sparks                                         -1   0   8 -1   9 -1
# Wicked: The Life and Times of the Wicked Witch ... -1  -1   9  0  -1  7
# Snow Falling on Cedars                              0  -1  10  9   0  0
# ...                                                ..  ..  .. ..  .. ..
# The Book of Ruth (Oprah's Book Club (Paperback))    0  -1   7 -1   0  0
# 1st to Die: A Novel                                 0   7  10 -1   9 -1
# Hannibal                                            0   0   8 -1   5 -1
# The Alienist                                        0   0   7 -1   0 -1
# Fahrenheit 451                                      0  10   0 -1   8  9
# The Runaway Jury                                    0   0   9 -1   0 -1
# A Prayer for Owen Meany                            -1  -1  10  0   0 -1
# The Joy Luck Club                                   0   8   0  9   0  8
# Summer Sisters                                      0  -1   7  0   9  0
# Red Dragon                                          0  -1   0 -1  -1 -1
# The Summons                                         0   0   8  0   8 -1
# The Secret Life of Bees                             0   8  10  0  10  0
# The Partner                                         0   0   0 -1   0 -1
# The Client                                          0   0   5 -1   5 -1
# Timeline                                            0   0  10  0   5 -1
# The Reader                                         -1   6   8  8   5  0
# Into Thin Air : A Personal Account of the Mt. E...  0  -1   8  0   5  0
# Angela's Ashes (MMP) : A Memoir                     0  -1   9  0  -1  0
# Where the Heart Is (Oprah's Book Club (Paperback))  0   0  10  9   8  0
# The Pilot's Wife : A Novel                          0   0   0  0   0  0
# The Nanny Diaries: A Novel                          0   8   9  0   9  8
# House of Sand and Fog                              -1   0   7  0   9  7
# Message in a Bottle                                 8   0   0  0   0  0
# Fall On Your Knees (Oprah #45)                     -1  -1   6  0   9  8
# Harry Potter and the Sorcerer's Stone (Harry Po...  0  10  10  0  -1  0
# A Time to Kill                                      0   0   0 -1   0 -1
# The Pelican Brief                                   0   0   0 -1   6 -1
# Balzac and the Little Chinese Seamstress : A Novel -1   8   9  0  -1 -1
# Angels &amp; Demons                                 0   0   8  0   0  0
# The Brethren                                        0   0   8  0  -1 -1
#
# [98 rows x 6 columns]

# %% [markdown]
# #####Mean normalization takes care of the case where a user hasn't rated a movie yet
# #####As a general rule is a movie hasn't receieved any ratings yet you probably shouldn't be recommending it, so we don't generally use mean normalization to fix this case
